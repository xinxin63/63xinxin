# %% [markdown]
# # Breaking down data.gov climate data

# %%
import requests
import requests_ftp
import requests_cache
import lxml
from bs4 import BeautifulSoup
from collections import Counter
from matplotlib import pyplot as plt
import pandas as pd
plt.style.use('ggplot')
requests_cache.install_cache('coll_cache')
# %matplotlib inline

# %% [markdown]
# I went to data.gov and selected the climate data tab.  Here is the url: https://catalog.data.gov/dataset?groups=climate5434&page=1
#
# Let's make a request for this page.  To install requests-ftp use pip.

# %%
urlbase = "https://catalog.data.gov/dataset"
dataparams = {"groups":"climate5434","page":1}
climreq = requests.get(urlbase,params = dataparams)

# %%
climhtml = climreq.text
clim = BeautifulSoup(climhtml,'lxml-xml')

# %%
print climhtml[:1000]
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]> <html lang="en" class="ie ie7"> <![endif]-->
# <!--[if IE 8]> <html lang="en" class="ie ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en"> <!--<![endif]-->
#   <head>
#     <!--[if lte ie 8]><script type="text/javascript" src="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/html5.min.js"></script><![endif]-->
# <link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/select2/select2.css" />
# <link rel="stylesheet" type="text/css" href="/fanstatic/css/:version:2017-02-02T20:01:48.94/main.min.css" />
# <link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/font-awesome/css/font-awesome.min.css" />
# <!--[if ie 7]><link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/font-awesome/css/font-awesome-ie7.min.css" /><![endif]-->
# <link rel="stylesheet" type="text/css" href="/fanstatic/ckanext-h

# %% [markdown]
# The text returns the raw html, and this can be converted into a BeautifulSoup object.  We will be using the lxml parser for this.

# %%
type(clim)
# Out:
# bs4.BeautifulSoup

# %%
print clim.prettify()[:1000]
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html>
# <!--[if IE 7]> <html lang="en" class="ie ie7"> <![endif]-->
# <!--[if IE 8]> <html lang="en" class="ie ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en" class="ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <!--[if lte ie 8]><script type="text/javascript" src="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/html5.min.js"></script><![endif]-->
#   <link href="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/select2/select2.css" rel="stylesheet" type="text/css"/>
#   <link href="/fanstatic/css/:version:2017-02-02T20:01:48.94/main.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/font-awesome/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
#   <!--[if ie 7]><link rel="stylesheet" type="text/css" href="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/font-awesome/css/font-awesome-ie7.min.css" /><![endif]-->
#   <link href="/fanstati

# %% [markdown]
# The BS object, and tags have other tags within then that you can access either as a class object (like below) or using the find method

# %%
print clim.body.prettify()
# Out:
# <body data-locale-root="https://catalog.data.gov/" data-site-root="https://catalog.data.gov/">
#  <div class="hide">
#   <a href="#content">
#    Skip to content
#   </a>
#  </div>
#  <a class="hide" href="#content">
#   Skip to content
#  </a>
#  <header class="navbar navbar-static-top masthead">
#   <div class="container">
#    <div class="searchbox-row skip-navigation">
#     <div class="skip-link">
#      <a href="#">
#       Jump to Content
#      </a>
#     </div>
#     <div>
#      <form action="/dataset" class="search-form form-inline navbar-right navbar-nav  col-sm-6 col-md-6 col-lg-6" method="get" role="search">
#       <div class="input-group">
#        <label class="hide" for="search-header">
#         Search for:
#        </label>
#        <input class="search-field form-control" id="search-header" name="q" onblur="if(value=='') value = 'Search Data.Gov'" onfocus="if(value=='Search Data.Gov') value = ''" placeholder="Search Data.Gov" type="search" value="Search Data.Gov">
#         <span class="input-group-btn">
#          <button class="search-submit btn_new btn-default" type="submit">
#           <i class="fa fa-search"/>
#           <span class="sr-only">
#            Search
#           </span>
#          </button>
#         </span>
#        </input>
#        <input name="as_sfid" type="hidden" value="AAAAAAU4KkzOjNWTE2bU8xGaa_BgeGlTfUq17G1Ft_7SJWOodAyDyMQqjpBvmAFFDI-FZcXqw3BY0MIvQmw3vcMEW2Kr7QjGxP2qVgO1ZW3uGpv35ZNzh8hBfeb6hhUZ6BJiZJE="/>
#        <input name="as_fid" type="hidden" value="7a2b10b09e882f17844c168f29efbede326117eb"/>
#       </div>
#      </form>
#     </div>
#     <hgroup class="top">
#      <div class="account-wrapper">
#      </div>
#     </hgroup>
#     <hgroup class="top-nav">
#      <div class="logo">
#       <a class="root" href="http://www.data.gov/">
#        <span>
#         data.gov
#        </span>
#       </a>
#      </div>
#      <button class="btn btn-navbar" data-target=".nav-primary" data-toggle="collapse" type="button">
#       <span class="icon-bar"/>
#       <span class="icon-bar"/>
#       <span class="icon-bar"/>
#      </button>
#      <div class="nav-primary nav-collapse collapse">
#       <nav class="primary">
#        <ul class="nav navbar-nav navbar-right" id="menu-primary-navigation">
#         <li class="active">
#          <a href="/dataset">
#           Data
#          </a>
#         </li>
#         <li class="dropdown yamm-fw menu-topics">
#          <a class="dropdown-toggle" data-toggle="dropdown">
#           Topics
#           <b class="caret"/>
#          </a>
#          <ul class="dropdown-menu topics">
#           <li class="menu-agriculture">
#            <a href="//www.data.gov/food/">
#             <i/>
#             <span>
#              Agriculture
#             </span>
#            </a>
#           </li>
#           <li class="menu-climate">
#            <a href="//www.data.gov/climate/">
#             <i/>
#             <span>
#              Climate
#             </span>
#            </a>
#           </li>
#           <li class="menu-consumer">
#            <a href="//www.data.gov/consumer/">
#             <i/>
#             <span>
#              Consumer
#             </span>
#            </a>
#           </li>
#           <li class="menu-ecosystems">
#            <a href="//www.data.gov/ecosystems/">
#             <i/>
#             <span>
#              Ecosystems
#             </span>
#            </a>
#           </li>
#           <li class="menu-education">
#            <a href="//www.data.gov/education/">
#             <i/>
#             <span>
#              Education
#             </span>
#            </a>
#           </li>
#           <li class="menu-energy">
#            <a href="//www.data.gov/energy/">
#             <i/>
#             <span>
#              Energy
#             </span>
#            </a>
#           </li>
#           <li class="menu-finance">
#            <a href="//www.data.gov/finance/">
#             <i/>
#             <span>
#              Finance
#             </span>
#            </a>
#           </li>
#           <li class="menu-health">
#            <a href="//www.data.gov/health/">
#             <i/>
#             <span>
#              Health
#             </span>
#            </a>
#           </li>
#           <li class="menu-local-government">
#            <a href="//www.data.gov/local/">
#             <i/>
#             <span>
#              Local Government
#             </span>
#            </a>
#           </li>
#           <li class="menu-manufacturing">
#            <a href="//www.data.gov/manufacturing/">
#             <i/>
#             <span>
#              Manufacturing
#             </span>
#            </a>
#           </li>
#           <li class="menu-maritime">
#            <a href="//www.data.gov/maritime/">
#             <i/>
#             <span>
#              Maritime
#             </span>
#            </a>
#           </li>
#           <li class="menu-ocean">
#            <a href="//www.data.gov/ocean/">
#             <i/>
#             <span>
#              Ocean
#             </span>
#            </a>
#           </li>
#           <li class="menu-public-safety">
#            <a href="//www.data.gov/safety/">
#             <i/>
#             <span>
#              Public Safety
#             </span>
#            </a>
#           </li>
#           <li class="menu-science-research">
#            <a href="//www.data.gov/research/">
#             <i/>
#             <span>
#              Science  Research
#             </span>
#            </a>
#           </li>
#          </ul>
#          <li>
#           <li>
#            <a href="//www.data.gov/impact/">
#             Impact
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/applications">
#             Applications
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/developers/">
#             Developers
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/contact">
#             Contact
#            </a>
#           </li>
#          </li>
#         </li>
#        </ul>
#       </nav>
#      </div>
#      <div class="header_new banner_new page-heading_new">
#       <div class="container">
#        <div class="page-header_new">
#         <div class="main-heading">
#          <h1>
#           <span class="category-header topic-climate">
#            <a class="topic_url" href="//www.data.gov/climate">
#             <div>
#              <i/>
#             </div>
#             <span class="topic_name">
#              Climate
#             </span>
#            </a>
#           </span>
#           Data Catalog
#          </h1>
#         </div>
#         <div class="toolbar">
#          <div class="add_action">
#           <a class="btn btn_new" href="/organization">
#            Organizations
#           </a>
#           <a class="btn btn-primary question" href="http://www.data.gov/catalog-help/">
#            <i class="icon-question-sign"/>
#           </a>
#          </div>
#          <ol class="breadcrumb">
#           <li class="home">
#            <a href="/dataset">
#             <i class="icon-home"/>
#             <span>
#              Home
#             </span>
#            </a>
#           </li>
#           <li class="active">
#            <a href="/dataset">
#             Datasets
#            </a>
#           </li>
#          </ol>
#         </div>
#        </div>
#       </div>
#      </div>
#     </hgroup>
#     <div class="sub-nav banner-nav">
#      <div class="container">
#       <nav class="topic-subnav" role="navigation">
#        <ul class="nav navbar-nav" id="menu-community">
#         <li>
#          <a class="dropdown-toggle" data-toggle="dropdown" href="//www.data.gov/#">
#           Themes
#           <b class="caret"/>
#          </a>
#          <ul class="dropdown-menu topics topic-climate ">
#           <li>
#            <a href="//www.data.gov/climate/arctic/">
#             Arctic
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/climate/coastalflooding/">
#             Coastal Flooding
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/climate/ecosystem-vulnerability/">
#             Ecosystem Vulnerability
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/climate/energy-infrastructure/">
#             Energy Infrastructure
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/climate/foodresilience/">
#             Food Resilience
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/climate/humanhealth/">
#             Human Health
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/climate/transportation/">
#             Transportation
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/climate/tribal-nations/">
#             Tribal Nations
#            </a>
#           </li>
#           <li>
#            <a href="//www.data.gov/climate/water/">
#             Water
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a class="active" href="//catalog.data.gov/dataset?groups=climate5434topic=climate_navigation">
#           Data
#          </a>
#         </li>
#         <li>
#          <a href="//www.data.gov/climate/portals/">
#           Resources
#          </a>
#         </li>
#         <li>
#          <a href="//www.data.gov/climate/climate-challenges">
#           Challenges
#          </a>
#         </li>
#         <li>
#          <a href="//www.data.gov/climate/faq/">
#           FAQ
#          </a>
#         </li>
#         <li>
#          <a href="//www.data.gov/climate/contact/">
#           Contact Climate
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#     <div class="controller-package action-search" role="main">
#      <div class="container" id="content">
#       <div class="toolbar">
#        <div class="module" style="margin:0px;">
#         <div class="faded disclaimer" style="margin-bottom:10px;visibility: hidden;height:0px;">
#          Federal datasets are subject to the U.S. Federal Government
#          <a href="//www.data.gov/data-policy">
#           <b>
#            Data Policy
#           </b>
#          </a>
#          . Non-federal participants (e.g., universities, organizations, and tribal, state, and local governments) maintain their own data policies. Data policies influence the usefulness of the data.
#          <a href="//www.data.gov/catalog-help">
#           <b>
#            Learn more
#           </b>
#          </a>
#          about how to search for data and use this catalog.
#         </div>
#         <form class="dataset-search clearfix" data-module="select-switch" id="dataset-search" method="get">
#          <span class="control-group search-giant">
#           <label class="hide" for="search-big">
#            Search datasets
#           </label>
#           <input autocomplete="off" class="search" id="search-big" name="q" onblur="if(value=='') value = 'Search datasets...'" onfocus="if(value=='Search datasets...') value = ''" placeholder="Search datasets..." type="text" value=""/>
#           <button type="submit" value="search">
#            Submit
#           </button>
#          </span>
#          <!-- Snippet snippets/sort_by.html start -->
#          <span class="form-select control-group control-order-by">
#           <label for="field-order-by">
#            Order by
#           </label>
#           <select id="field-order-by" name="sort">
#            <option value="score desc, name asc">
#             Relevance
#            </option>
#            <option value="title_string asc">
#             Name Ascending
#            </option>
#            <option value="title_string desc">
#             Name Descending
#            </option>
#            <option value="metadata_modified desc">
#             Last Modified
#            </option>
#            <option selected="selected" value="views_recent desc">
#             Popular
#            </option>
#            <option value="metadata_created desc">
#             Date Added
#            </option>
#           </select>
#           <button class="btn js-hide" type="submit">
#            Go
#           </button>
#          </span>
#          <!-- Snippet snippets/sort_by.html end -->
#          <span>
#           <input name="groups" type="hidden" value="climate5434"/>
#          </span>
#          <br clear="both"/>
#          <div id="dataset-search-ext"/>
#          <div class="results">
#           <div id="sort_option">
#           </div>
#           <div class="filter-list">
#            <span class="facet">
#             Topics:
#            </span>
#            <span class="filtered pill">
#             Climate
#             <a class="remove" href="/dataset" title="Remove">
#              <i class="icon-remove"/>
#             </a>
#            </span>
#           </div>
#          </div>
#          <input name="as_sfid" type="hidden" value="AAAAAAXy22dDbNlwhIeEsKl5fXvz66JEX2CzQKyVCXeglIbkFbqQD7NY37XczyoYufjaCfTeU8jNcdo6Es2HQ7E2pAb4lgQoksKfRtDVZMsLsWmyE_-lO9CQSiNmeTh-oBtpBu8="/>
#          <input name="as_fid" type="hidden" value="15d53ffacba441060e1c0c5f90ac4d93d17e4416"/>
#         </form>
#        </div>
#        <a class="show-filters btn">
#         Filter Results
#        </a>
#       </div>
#       <div class="row wrapper">
#        <div class="primary span9">
#         <section class="module">
#          <div class="new-results">
#           <!-- Snippet snippets/search_result_text.html start -->
#           666 datasets found
#           <!-- Snippet snippets/search_result_text.html end -->
#          </div>
#          <div class="module-content">
#           <!-- Snippet snippets/package_list.html start -->
#           <ul class="dataset-list unstyled">
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <span class="dataset-collection label">
#                <i class="icon-collection"/>
#                Collection
#               </span>
#               <a href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">
#                1 meter Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="256 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                256 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                U.S. Geological Survey, Department of the Interior
#               </p>
#               <div>
#                This is a tiled collection of the 3D Elevation Program (3DEP) and is one meter resolution. Data in this layer represent a bare earth surface.The 3DEP data holdings...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1_meter/">
#                 WAF
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="img" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/1m/IMG/">
#                 IMG
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer" target="_blank">
#                 Esri REST
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-/resource/98e1752e-cf04-4df3-be2f-b58bee5a3c06">
#                 WMS
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://nationalmap.gov/elevation.html" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://viewer.nationalmap.gov/" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="more" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">
#                 1 more in dataset
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/u-s-hourly-precipitation-data">
#                U.S. Hourly Precipitation Data
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="210 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                210 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                National Oceanic and Atmospheric Administration, Department of Commerce
#               </p>
#               <div>
#                Hourly Precipitation Data (HPD) is digital data set DSI-3240, archived at the National Climatic Data Center (NCDC). The primary source of data for this file is...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/all-records/catalog/search/resource/details.page?id=gov.noaa.ncdc:C00313" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/cdo-web/search?datasetid=PRECIP_HLY#" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="https://gis.ncdc.noaa.gov/maps/ncei/cdo/hourly?layers=001" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="ftp://ftp.ncdc.noaa.gov/pub/data/hourly_precip-3240/" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="esri rest" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/arcgis/rest/services/cdo/precip_hly/MapServer" target="_blank">
#                 Esri REST
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="kmz" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="/dataset/u-s-hourly-precipitation-data/resource/f21b5e68-f516-4431-bd01-a5f0b4cd5765">
#                 KMZ
#                </a>
#               </li>
#               <li>
#                <a class="more" href="/dataset/u-s-hourly-precipitation-data">
#                 11 more in dataset
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/farm-programs-payments">
#                Farm Programs Payments
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="170 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                170 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                Department of Agriculture
#               </p>
#               <div>
#                Payments made by the Department of Agriculture, Farm Service Agency to US agricultural producers participating in Farm Bill programs including commodity, price...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="html" data-organization="Department of Agriculture" href="https://www.fsa.usda.gov/FSA/webapp?area=newsroom&amp;subject=landing&amp;topic=foi-er-fri-pfi" target="_blank">
#                 HTML
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/national-flood-hazard-layer-nfhl">
#                National Flood Hazard Layer (NFHL)
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="162 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                162 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                Department of Homeland Security
#               </p>
#               <div>
#                The National Flood Hazard Layer (NFHL) is a compilation of GIS data that comprises a nationwide digital Flood Insurance Rate Map. The GIS data and services are...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="nfhl status page" data-organization="Department of Homeland Security" href="http://www.floodmaps.fema.gov/NFHL/status.shtml">
#                 NFHL Status Page
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="nfhl interactive map (fema geoplatform)" data-organization="Department of Homeland Security" href="http://fema.maps.arcgis.com/home/item.html?id=cbe088e7c8704464aa0fc34eb99e7f30">
#                 NFHL Interactive Map (FEMA GeoPlatform)
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="fact sheet: national flood hazard layer (nfhl)" data-organization="Department of Homeland Security" href="http://www.fema.gov/media-library/assets/documents/13424">
#                 Fact Sheet: National Flood Hazard Layer (NFHL)
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="get flood maps and data from fema" data-organization="Department of Homeland Security" href="http://msc.fema.gov">
#                 Get Flood Maps and Data from FEMA
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="download seamless nationwide nfhl gis data" data-organization="Department of Homeland Security" href="https://content.femadata.com/FIMA/Risk_MAP/NFHL/">
#                 Download Seamless Nationwide NFHL GIS data
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="pdf" data-organization="Department of Homeland Security" href="http://www.fema.gov/media-library-data/1449862521789-e97ed4c7b7405faa7c3691603137ec40/FIRM_Database_Technical_Reference_Nov_2015.pdf">
#                 PDF
#                </a>
#               </li>
#               <li>
#                <a class="more" href="/dataset/national-flood-hazard-layer-nfhl">
#                 1 more in dataset
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/food-environment-atlas-f4a22">
#                Food Environment Atlas
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="127 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                127 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                Department of Agriculture
#               </p>
#               <div>
#                Food environment factors--such as store/restaurant proximity, food prices, food and nutrition assistance programs, and community characteristics--interact to...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="html" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/food-environment-atlas/go-to-the-atlas.aspx" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="api" data-organization="Department of Agriculture" href="https://gis.ers.usda.gov/arcgis/rest/services/" target="_blank">
#                 API
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/food-environment-atlas/data-access-and-documentation-downloads/" target="_blank">
#                 HTML
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/food-price-outlook">
#                Food Price Outlook
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="125 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                125 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                Department of Agriculture
#               </p>
#               <div>
#                The Consumer Price Index (CPI) for food is a component of the all-items CPI. The CPI measures the average change over time in the prices paid by urban consumers for...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="xls" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/food-price-outlook.aspx">
#                 XLS
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/military-installations-ranges-and-training-areas">
#                Military Installations, Ranges, and Training Areas
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="94 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                94 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                Department of Defense
#               </p>
#               <div>
#                This dataset, released by DoD, contains geographic information for major installations, ranges, and training areas in the United States and its territories. This...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="zip" data-organization="Department of Defense" href="http://www.acq.osd.mil/eie/Downloads/DISDI/installations_ranges.zip">
#                 ZIP
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/ncdc-storm-events-database">
#                NCDC Storm Events Database
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="94 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                94 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                National Oceanic and Atmospheric Administration, Department of Commerce
#               </p>
#               <div>
#                Storm Data is provided by the National Weather Service (NWS) and contain statistics on personal injuries and damage estimates. Storm Data covers the United States of...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="xml" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/all-records/catalog/search/resource/details.page?id=gov.noaa.ncdc:C00510">
#                 XML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="xml" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/stormevents/ftp.jsp">
#                 XML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/stormevents/faq.jsp" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/stormevents/ftp.jsp" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/stormevents/" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncei.noaa.gov" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="more" href="/dataset/ncdc-storm-events-database">
#                 5 more in dataset
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/statistical-abstract-of-the-united-states">
#                Statistical Abstract of the United States
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="93 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                93 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                Department of Commerce
#               </p>
#               <div>
#                First published in 1878, the Statistical Abstract serves as the official federal summary of statistics and provides over 1,400 tables of benchmark measures on the...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="txt/html" data-organization="Department of Commerce" href="http://www.census.gov/library/publications/time-series/statistical_abstracts.html">
#                 txt/html
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <span class="dataset-collection label">
#                <i class="icon-collection"/>
#                Collection
#               </span>
#               <a href="/dataset/usgs-national-transportation-dataset-ntd-downloadable-data-collectionde7d2">
#                USGS National Transportation Dataset (NTD) Downloadable Data Collection
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="91 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                91 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                U.S. Geological Survey, Department of the Interior
#               </p>
#               <div>
#                The USGS Transportation downloadable data from The National Map (TNM) is based on TIGER/Line data provided through U.S. Census Bureau and supplemented with HERE road...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/transportation/ntd/">
#                 WAF
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="filegdb" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Tran/GDB/">
#                 FileGDB
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="shp" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Tran/Shape/">
#                 SHP
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="https://services.nationalmap.gov/arcgis/rest/services/transportation/MapServer" target="_blank">
#                 Esri REST
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-national-transportation-dataset-ntd-downloadable-data-collectionde7d2/resource/74a63591-bed6-457d-9e40-44b64545b07c">
#                 WMS
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="wfs" data-organization="U.S. Geological Survey, Department of the Interior" href="http://services.nationalmap.gov/arcgis/services/WFS/transportation/MapServer/WFSServer?request=GetCapabilities&amp;service=WFS">
#                 WFS
#                </a>
#               </li>
#               <li>
#                <a class="more" href="/dataset/usgs-national-transportation-dataset-ntd-downloadable-data-collectionde7d2">
#                 1 more in dataset
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/u-s-monthly-climate-normals-1981-2010">
#                U.S. Monthly Climate Normals (1981-2010)
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="86 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                86 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                National Oceanic and Atmospheric Administration, Department of Commerce
#               </p>
#               <div>
#                The U.S. Monthly Climate Normals for 1981 to 2010 are 30-year averages of meteorological parameters for thousands of U.S. stations located across the 50 states, as...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/all-records/catalog/search/resource/details.page?id=gov.noaa.ncdc:C00822" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="ftp://ftp.ncdc.noaa.gov/pub/data/normals/1981-2010/" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/cdo-web/search?datasetid=NORMAL_MLY" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="https://gis.ncdc.noaa.gov/maps/ncei/normals&amp;layers=001" target="_blank">
#                 HTML
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="esri rest" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/arcgis/rest/services/cdo/normals/MapServer" target="_blank">
#                 Esri REST
#                </a>
#               </li>
#               <li>
#                <a class="label" data-format="kmz" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="/dataset/u-s-monthly-climate-normals-1981-2010/resource/29762c82-7f32-47b0-b809-5e3f9408eb8f">
#                 KMZ
#                </a>
#               </li>
#               <li>
#                <a class="more" href="/dataset/u-s-monthly-climate-normals-1981-2010">
#                 18 more in dataset
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/fruit-and-vegetable-prices">
#                Fruit and Vegetable Prices
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="85 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                85 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                Department of Agriculture
#               </p>
#               <div>
#                How much do fruits and vegetables cost? ERS estimated average prices for 153 commonly consumed fresh and processed fruits and vegetables.
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="xls" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/fruit-and-vegetable-prices.aspx">
#                 XLS
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
#               <span class="organization-type" data-organization-type="federal" title="Federal Government">
#                <span>
#                 Federal
#                </span>
#               </span>
#              </div>
#              <h3 class="dataset-heading">
#               <a href="/dataset/mypyramid-food-raw-data-f9ed6">
#                MyPyramid Food Raw Data
#               </a>
#               <!-- Snippet snippets/popular.html start -->
#               <span class="recent-views" title="77 recent views" xmlns="http://www.w3.org/1999/xhtml">
#                <i class="fa fa-line-chart"/>
#                77 recent views
#               </span>
#               <!-- Snippet snippets/popular.html end -->
#              </h3>
#              <div class="notes">
#               <p class="dataset-organization">
#                Department of Agriculture
#               </p>
#               <div>
#                MyPyramid Food Data provides information on the total calories; calories from solid fats, added sugars, and alcohol (extras); MyPyramid food group and subgroup...
#               </div>
#              </div>
#              <ul class="dataset-resources unstyled">
#               <li>
#                <a class="label" data-format="zip" data-organization="Department of Agriculture" href="https://www.cnpp.usda.gov/Innovations/DataSource/MyFoodapediaData.zip" target="_blank">
#                 ZIP
#                </a>
#               </li>
#              </ul>
#             </div>
#            </li>
#            <!-- Snippet snippets/package_item.html end -->
#            <!-- Snippet snippets/package_item.html start -->
#            <li class="dataset-item has-organization">
#             <div class="dataset-content">
#              <div class="organization-type-wrap">
# ...
#              <li class="nav-item">
#               <a href="/dataset?publisher=Federal+Transit+Administration&amp;groups=climate5434" title="Federal Transit Administration">
#                <span>
#                 Federal Transit Adm... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?publisher=Federal+Highway+Administration&amp;groups=climate5434" title="Federal Highway Administration">
#                <span>
#                 Federal Highway Adm... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?publisher=Farm+Service+Agency%2C+Department+of+Agriculture&amp;groups=climate5434" title="Farm Service Agency, Department of Agriculture">
#                <span>
#                 Farm Service Agency... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?publisher=Economic+Research+Service%2C+US+Department+of+Agriculture&amp;groups=climate5434" title="Economic Research Service, US Department of Agriculture">
#                <span>
#                 Economic Research S... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?publisher=Department+of+Health+%26amp%3B+Human+Services&amp;groups=climate5434" title="Department of Health &amp;amp; Human Services">
#                <span>
#                 Department of Healt... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?publisher=Department+of+Defense&amp;groups=climate5434" title="">
#                <span>
#                 Department of Defense (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;publisher=DOE+Electricity+Delivery+and+Energy+Reliability" title="DOE Electricity Delivery and Energy Reliability">
#                <span>
#                 DOE Electricity Del... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?publisher=Argonne+National+Laboratory&amp;groups=climate5434" title="Argonne National Laboratory">
#                <span>
#                 Argonne National La... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;publisher=Animal+and+Plant+Health+Inspection+Service%2C+Department+of+Agriculture" title="Animal and Plant Health Inspection Service, Department of Agriculture">
#                <span>
#                 Animal and Plant He... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?publisher=Animal+and+Plant+Health+Inspection+Service&amp;groups=climate5434" title="Animal and Plant Health Inspection Service">
#                <span>
#                 Animal and Plant He... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?publisher=Agency+for+Healthcare+Research+and+Quality%2C+Department+of+Health+%26amp%3B+Human+Services&amp;groups=climate5434" title="Agency for Healthcare Research and Quality, Department of Health &amp;amp; Human Services">
#                <span>
#                 Agency for Healthca... (1)
#                </span>
#               </a>
#              </li>
#             </ul>
#            </nav>
#           </section>
#           <!-- Snippet snippets/facet_list.html end -->
#           <!-- Snippet snippets/facet_list.html start -->
#           <section class="module module-narrow module-shallow">
#            <h2 class="module-heading" id="sec-bureauCode">
#             <i class="icon-medium icon-filter"/>
#             <span>
#              Bureaus
#             </span>
#             <img id="sortFacetAlpha" src="/fanstatic/datagovtheme/images/alpha.png"/>
#             <img id="sortFacetCount" src="/fanstatic/datagovtheme/images/number.png"/>
#             <a class="action" href="/dataset?groups=climate5434">
#              Clear All
#             </a>
#            </h2>
#            <nav>
#             <ul class="unstyled nav nav-simple nav-facet" id="bureauCode" name="facet">
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=026%3A00&amp;groups=climate5434" title="National Aeronautics and Space Administration">
#                <span>
#                 National Aeronautic... (115)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=019%3A20&amp;groups=climate5434" title="">
#                <span>
#                 Energy Programs (42)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=005%3A13&amp;groups=climate5434" title="Economic Research Service">
#                <span>
#                 Economic Research S... (40)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;bureauCode=009%3A20" title="Centers for Disease Control and Prevention">
#                <span>
#                 Centers for Disease... (26)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;bureauCode=005%3A53" title="Natural Resources Conservation Service">
#                <span>
#                 Natural Resources C... (6)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=005%3A18&amp;groups=climate5434" title="Agricultural Research Service">
#                <span>
#                 Agricultural Resear... (5)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=006%3A07&amp;groups=climate5434" title="">
#                <span>
#                 Bureau of the Census (4)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;bureauCode=010%3A18" title="United States Fish and Wildlife Service">
#                <span>
#                 United States Fish ... (3)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;bureauCode=005%3A68" title="Foreign Agricultural Service">
#                <span>
#                 Foreign Agricultura... (3)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=005%3A15&amp;groups=climate5434" title="National Agricultural Statistics Service">
#                <span>
#                 National Agricultur... (3)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;bureauCode=025%3A06" title="Community Planning and Development">
#                <span>
#                 Community Planning ... (2)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=005%3A84&amp;groups=climate5434" title="Food and Nutrition Service">
#                <span>
#                 Food and Nutrition ... (2)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=005%3A32&amp;groups=climate5434" title="Animal and Plant Health Inspection Service">
#                <span>
#                 Animal and Plant He... (2)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;bureauCode=021%3A50" title="Pipeline and Hazardous Materials Safety Administration">
#                <span>
#                 Pipeline and Hazard... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=021%3A36&amp;groups=climate5434" title="Federal Transit Administration">
#                <span>
#                 Federal Transit Adm... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=021%3A15&amp;groups=climate5434" title="Federal Highway Administration">
#                <span>
#                 Federal Highway Adm... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;bureauCode=009%3A38" title="Centers for Medicare and Medicaid Services">
#                <span>
#                 Centers for Medicar... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=007%3A00&amp;groups=climate5434" title="Department of Defense - Military Programs">
#                <span>
#                 Department of Defen... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=006%3A48&amp;groups=climate5434" title="National Oceanic and Atmospheric Administration">
#                <span>
#                 National Oceanic an... (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?groups=climate5434&amp;bureauCode=005%3A49" title="">
#                <span>
#                 Farm Service Agency (1)
#                </span>
#               </a>
#              </li>
#              <li class="nav-item">
#               <a href="/dataset?bureauCode=000%3A00&amp;groups=climate5434" title="">
#                <span>
#                 Code 000:00 (1)
#                </span>
#               </a>
#              </li>
#             </ul>
#            </nav>
#           </section>
#           <!-- Snippet snippets/facet_list.html end -->
#          </div>
#          <a class="close no-text hide-filters">
#           <i class="icon-remove-sign"/>
#           <span class="text">
#            close
#           </span>
#          </a>
#         </div>
#        </aside>
#       </div>
#      </div>
#     </div>
#     <footer class="site-footer">
#      <div class="container">
#       <div class="fluid-row">
#        <div class="span6 clearfix">
#         <div class="footer-logo">
#          <a class="logo-brand" href="http://www.data.gov/">
#           Data.Gov 2.0
#          </a>
#         </div>
#         <ul class="nav" id="menu-footer2">
#          <!-- Snippet snippets/footer2_menu.html start -->
#          <li>
#           <a href="//www.data.gov/privacy-policy">
#            Privacy and Website Policies
#           </a>
#          </li>
#          <li>
#           <a href="//www.usa.gov/">
#            USA.GOV
#           </a>
#          </li>
#          <li>
#           <a href="//www.performance.gov/">
#            PERFORMANCE.GOV
#           </a>
#          </li>
#          <!-- Snippet snippets/footer2_menu.html end -->
#         </ul>
#        </div>
#        <nav class="span3" role="navigation">
#         <ul class="nav" id="menu-footer">
#          <!-- Snippet snippets/footer_menu.html start -->
#          <li>
#           <a href="//www.data.gov/about">
#            About
#           </a>
#          </li>
#          <li>
#           <a href="//www.data.gov/open-gov/">
#            Open Government
#           </a>
#          </li>
#          <li>
#           <a href="//www.data.gov/meta/">
#            Blog
#           </a>
#          </li>
#          <li>
#           <a href="//www.data.gov/metrics">
#            Metrics
#           </a>
#          </li>
#          <li>
#           <a href="//www.data.gov/events/">
#            Events
#           </a>
#          </li>
#          <!-- Snippet snippets/footer_menu.html end -->
#          <li>
#           <a class="local-link" href="/user/login">
#            Login
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <div class="span3 social-nav">
#         <nav role="navigation">
#          <ul class="nav" id="menu-social_navigation">
#           <li>
#            <a href="https://twitter.com/usdatagov">
#             <i class="fa fa-twitter"/>
#             <span>
#              Twitter
#             </span>
#            </a>
#           </li>
#           <li>
#            <a href="http://github.com/GSA/data.gov/">
#             <i class="fa fa-github"/>
#             <span>
#              Github
#             </span>
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <script>
#      var extlink_white_list = '.gov,.mil'.split(',');
#       var extlink_popup_message = 'This link will direct you to an external website that may have different content and privacy policies from Data.gov.';
#     </script>
#     <input data-module="googleanalyticsbasic_events" type="hidden"/>
#     <script>
#      document.getElementsByTagName('html')[0].className += ' js';
#     </script>
#     <script src="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/jquery.min.js" type="text/javascript"/>
#     <script src="/fanstatic/vendor/:version:2017-02-02T20:01:49.31/:bundle:bootstrap/js/bootstrap.min.js;jed.min.js;select2/select2.min.js" type="text/javascript"/>
#     <script src="/fanstatic/base/:version:2017-02-02T20:01:49.16/:bundle:plugins/jquery.inherit.min.js;plugins/jquery.proxy-all.min.js;plugins/jquery.url-helpers.min.js;plugins/jquery.date-helpers.min.js;plugins/jquery.slug.min.js;plugins/jquery.slug-preview.min.js;plugins/jquery.truncator.min.js;plugins/jquery.masonry.min.js;plugins/jquery.form-warning.min.js;sandbox.min.js;module.min.js;pubsub.min.js;client.min.js;notify.min.js;i18n.min.js;main.min.js;modules/select-switch.min.js;modules/slug-preview.min.js;modules/basic-form.min.js;modules/confirm-action.min.js;modules/api-info.min.js;modules/autocomplete.min.js;modules/custom-fields.min.js;modules/related-item.min.js;modules/data-viewer.min.js;modules/table-selectable-rows.min.js;modules/resource-form.min.js;modules/resource-upload-field.min.js;modules/resource-reorder.min.js;modules/resource-view-reorder.min.js;modules/follow.min.js;modules/activity-stream.min.js;modules/dashboard.min.js;modules/resource-view-embed.min.js;view-filters.min.js;modules/resource-view-filters-form.min.js;modules/resource-view-filters.min.js;modules/table-toggle-more.min.js;modules/dataset-visibility.min.js;modules/media-grid.min.js;modules/image-upload.min.js" type="text/javascript"/>
#     <script src="/fanstatic/base/:version:2017-02-02T20:01:49.16/tracking.min.js" type="text/javascript"/>
#     <script src="/fanstatic/datagovtheme/:version:2017-02-02T20:01:52.01/:bundle:scripts/vendor/leaflet/leaflet.js;scripts/vendor/leaflet.draw/leaflet.draw.js;scripts/spatial_query.js;scripts/location_autocomplete.js" type="text/javascript"/>
#     <!--[if lte ie 9]><script type="text/javascript" src="/fanstatic/datagovtheme/:version:2017-02-02T20:01:52.01/scripts/vendor/jquery.placeholder.js"></script><![endif]-->
#     <script src="/fanstatic/datagovtheme/:version:2017-02-02T20:01:52.01/scripts/jquery.cookie.js" type="text/javascript"/>
#     <script src="/fanstatic/datagovtheme/:version:2017-02-02T20:01:52.01/scripts/datagovtheme.js" type="text/javascript"/>
#     <script src="/fanstatic/datagovtheme/:version:2017-02-02T20:01:52.01/:bundle:scripts/tracking.js;scripts/hideMaxListItem.js;scripts/sorting.js" type="text/javascript"/>
#     <script src="/fanstatic/extlink/:version:2017-02-02T20:01:53.36/extlink.js" type="text/javascript"/>
#     <script src="/fanstatic/googleanalyticsbasic/:version:2017-02-02T20:01:58.61/googleanalyticsbasic_events.js" type="text/javascript"/>
#    </div>
#   </div>
#  </header>
# </body>

# %%
collset_content = clim.find_all(name='div',attrs={'class':'dataset-content'})

# %%
collset_content
# Out:
# [<div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<span class="dataset-collection label">\n<i class="icon-collection"/>\n                Collection\n            </span>\n<a href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">1 meter Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="256 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 256 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">U.S. Geological Survey, Department of the Interior </p>\n<div>This is a tiled collection of the 3D Elevation Program (3DEP) and is one meter resolution. Data in this layer represent a bare earth surface.The 3DEP data holdings...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1_meter/">WAF</a>\n</li>\n<li>\n<a class="label" data-format="img" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/1m/IMG/">IMG</a>\n</li>\n<li>\n<a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer" target="_blank">Esri REST</a>\n</li>\n<li>\n<a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-/resource/98e1752e-cf04-4df3-be2f-b58bee5a3c06">WMS</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://nationalmap.gov/elevation.html" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://viewer.nationalmap.gov/" target="_blank">HTML</a>\n</li>\n<li>\n<a class="more" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">1 more in dataset</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/u-s-hourly-precipitation-data">U.S. Hourly Precipitation Data</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="210 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 210 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">National Oceanic and Atmospheric Administration, Department of Commerce </p>\n<div>Hourly Precipitation Data (HPD) is digital data set DSI-3240, archived at the National Climatic Data Center (NCDC). The primary source of data for this file is...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/all-records/catalog/search/resource/details.page?id=gov.noaa.ncdc:C00313" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/cdo-web/search?datasetid=PRECIP_HLY#" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="https://gis.ncdc.noaa.gov/maps/ncei/cdo/hourly?layers=001" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="ftp://ftp.ncdc.noaa.gov/pub/data/hourly_precip-3240/" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="esri rest" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/arcgis/rest/services/cdo/precip_hly/MapServer" target="_blank">Esri REST</a>\n</li>\n<li>\n<a class="label" data-format="kmz" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="/dataset/u-s-hourly-precipitation-data/resource/f21b5e68-f516-4431-bd01-a5f0b4cd5765">KMZ</a>\n</li>\n<li>\n<a class="more" href="/dataset/u-s-hourly-precipitation-data">11 more in dataset</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/farm-programs-payments">Farm Programs Payments</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="170 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 170 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Agriculture </p>\n<div>Payments made by the Department of Agriculture, Farm Service Agency to US agricultural producers participating in Farm Bill programs including commodity, price...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="html" data-organization="Department of Agriculture" href="https://www.fsa.usda.gov/FSA/webapp?area=newsroom&amp;subject=landing&amp;topic=foi-er-fri-pfi" target="_blank">HTML</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/national-flood-hazard-layer-nfhl">National Flood Hazard Layer (NFHL)</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="162 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 162 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Homeland Security </p>\n<div>The National Flood Hazard Layer (NFHL) is a compilation of GIS data that comprises a nationwide digital Flood Insurance Rate Map. The GIS data and services are...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="nfhl status page" data-organization="Department of Homeland Security" href="http://www.floodmaps.fema.gov/NFHL/status.shtml">NFHL Status Page</a>\n</li>\n<li>\n<a class="label" data-format="nfhl interactive map (fema geoplatform)" data-organization="Department of Homeland Security" href="http://fema.maps.arcgis.com/home/item.html?id=cbe088e7c8704464aa0fc34eb99e7f30">NFHL Interactive Map (FEMA GeoPlatform)</a>\n</li>\n<li>\n<a class="label" data-format="fact sheet: national flood hazard layer (nfhl)" data-organization="Department of Homeland Security" href="http://www.fema.gov/media-library/assets/documents/13424">Fact Sheet: National Flood Hazard Layer (NFHL)</a>\n</li>\n<li>\n<a class="label" data-format="get flood maps and data from fema" data-organization="Department of Homeland Security" href="http://msc.fema.gov">Get Flood Maps and Data from FEMA</a>\n</li>\n<li>\n<a class="label" data-format="download seamless nationwide nfhl gis data" data-organization="Department of Homeland Security" href="https://content.femadata.com/FIMA/Risk_MAP/NFHL/">Download Seamless Nationwide NFHL GIS data</a>\n</li>\n<li>\n<a class="label" data-format="pdf" data-organization="Department of Homeland Security" href="http://www.fema.gov/media-library-data/1449862521789-e97ed4c7b7405faa7c3691603137ec40/FIRM_Database_Technical_Reference_Nov_2015.pdf">PDF</a>\n</li>\n<li>\n<a class="more" href="/dataset/national-flood-hazard-layer-nfhl">1 more in dataset</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/food-environment-atlas-f4a22">Food Environment Atlas</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="127 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 127 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Agriculture </p>\n<div>Food environment factors--such as store/restaurant proximity, food prices, food and nutrition assistance programs, and community characteristics--interact to...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="html" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/food-environment-atlas/go-to-the-atlas.aspx" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="api" data-organization="Department of Agriculture" href="https://gis.ers.usda.gov/arcgis/rest/services/" target="_blank">API</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/food-environment-atlas/data-access-and-documentation-downloads/" target="_blank">HTML</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/food-price-outlook">Food Price Outlook</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="125 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 125 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Agriculture </p>\n<div>The Consumer Price Index (CPI) for food is a component of the all-items CPI. The CPI measures the average change over time in the prices paid by urban consumers for...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="xls" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/food-price-outlook.aspx">XLS</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/military-installations-ranges-and-training-areas">Military Installations, Ranges, and Training Areas</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="94 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 94 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Defense </p>\n<div>This dataset, released by DoD, contains geographic information for major installations, ranges, and training areas in the United States and its territories. This...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="zip" data-organization="Department of Defense" href="http://www.acq.osd.mil/eie/Downloads/DISDI/installations_ranges.zip">ZIP</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/ncdc-storm-events-database">NCDC Storm Events Database</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="94 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 94 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">National Oceanic and Atmospheric Administration, Department of Commerce </p>\n<div>Storm Data is provided by the National Weather Service (NWS) and contain statistics on personal injuries and damage estimates. Storm Data covers the United States of...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="xml" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/all-records/catalog/search/resource/details.page?id=gov.noaa.ncdc:C00510">XML</a>\n</li>\n<li>\n<a class="label" data-format="xml" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/stormevents/ftp.jsp">XML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/stormevents/faq.jsp" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/stormevents/ftp.jsp" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/stormevents/" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncei.noaa.gov" target="_blank">HTML</a>\n</li>\n<li>\n<a class="more" href="/dataset/ncdc-storm-events-database">5 more in dataset</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/statistical-abstract-of-the-united-states">Statistical Abstract of the United States</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="93 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 93 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Commerce </p>\n<div>First published in 1878, the Statistical Abstract serves as the official federal summary of statistics and provides over 1,400 tables of benchmark measures on the...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="txt/html" data-organization="Department of Commerce" href="http://www.census.gov/library/publications/time-series/statistical_abstracts.html">txt/html</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<span class="dataset-collection label">\n<i class="icon-collection"/>\n                Collection\n            </span>\n<a href="/dataset/usgs-national-transportation-dataset-ntd-downloadable-data-collectionde7d2">USGS National Transportation Dataset (NTD) Downloadable Data Collection</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="91 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 91 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">U.S. Geological Survey, Department of the Interior </p>\n<div>The USGS Transportation downloadable data from The National Map (TNM) is based on TIGER/Line data provided through U.S. Census Bureau and supplemented with HERE road...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/transportation/ntd/">WAF</a>\n</li>\n<li>\n<a class="label" data-format="filegdb" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Tran/GDB/">FileGDB</a>\n</li>\n<li>\n<a class="label" data-format="shp" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Tran/Shape/">SHP</a>\n</li>\n<li>\n<a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="https://services.nationalmap.gov/arcgis/rest/services/transportation/MapServer" target="_blank">Esri REST</a>\n</li>\n<li>\n<a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-national-transportation-dataset-ntd-downloadable-data-collectionde7d2/resource/74a63591-bed6-457d-9e40-44b64545b07c">WMS</a>\n</li>\n<li>\n<a class="label" data-format="wfs" data-organization="U.S. Geological Survey, Department of the Interior" href="http://services.nationalmap.gov/arcgis/services/WFS/transportation/MapServer/WFSServer?request=GetCapabilities&amp;service=WFS">WFS</a>\n</li>\n<li>\n<a class="more" href="/dataset/usgs-national-transportation-dataset-ntd-downloadable-data-collectionde7d2">1 more in dataset</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/u-s-monthly-climate-normals-1981-2010">U.S. Monthly Climate Normals (1981-2010)</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="86 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 86 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">National Oceanic and Atmospheric Administration, Department of Commerce </p>\n<div>The U.S. Monthly Climate Normals for 1981 to 2010 are 30-year averages of meteorological parameters for thousands of U.S. stations located across the 50 states, as...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/all-records/catalog/search/resource/details.page?id=gov.noaa.ncdc:C00822" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="ftp://ftp.ncdc.noaa.gov/pub/data/normals/1981-2010/" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://www.ncdc.noaa.gov/cdo-web/search?datasetid=NORMAL_MLY" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="html" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="https://gis.ncdc.noaa.gov/maps/ncei/normals&amp;layers=001" target="_blank">HTML</a>\n</li>\n<li>\n<a class="label" data-format="esri rest" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="http://gis.ncdc.noaa.gov/arcgis/rest/services/cdo/normals/MapServer" target="_blank">Esri REST</a>\n</li>\n<li>\n<a class="label" data-format="kmz" data-organization="National Oceanic and Atmospheric Administration, Department of Commerce" href="/dataset/u-s-monthly-climate-normals-1981-2010/resource/29762c82-7f32-47b0-b809-5e3f9408eb8f">KMZ</a>\n</li>\n<li>\n<a class="more" href="/dataset/u-s-monthly-climate-normals-1981-2010">18 more in dataset</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/fruit-and-vegetable-prices">Fruit and Vegetable Prices</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="85 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 85 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Agriculture </p>\n<div>How much do fruits and vegetables cost? ERS estimated average prices for 153 commonly consumed fresh and processed fruits and vegetables.\n</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="xls" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/fruit-and-vegetable-prices.aspx">XLS</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/mypyramid-food-raw-data-f9ed6">MyPyramid Food Raw Data</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="77 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 77 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Agriculture </p>\n<div>MyPyramid Food Data provides information on the total calories; calories from solid fats, added sugars, and alcohol (extras); MyPyramid food group and subgroup...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="zip" data-organization="Department of Agriculture" href="https://www.cnpp.usda.gov/Innovations/DataSource/MyFoodapediaData.zip" target="_blank">ZIP</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/cdc-wonder-cancer-statistics">CDC WONDER: Cancer Statistics</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="72 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 72 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">U.S. Department of Health  Human Services </p>\n<div>The United States Cancer Statistics (USCS) online databases in WONDER provide cancer incidence and mortality data for the United States for the years since 1999, by...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="query tool" data-organization="U.S. Department of Health &amp; Human Services" href="http://wonder.cdc.gov/cancer.html">query tool</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/population-estimates">Population Estimates</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="72 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 72 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Commerce </p>\n<div>The program publishes estimates of the population by age, sex, race, and Hispanic origin for the nation, states, and counties. It also provides estimates of the...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="html" data-organization="Department of Commerce" href="http://www.census.gov/popest/data/index.html" target="_blank">HTML</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/commodity-flow-survey">Commodity Flow Survey</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="70 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 70 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Commerce </p>\n<div>The Commodity Flow Survey provides information on commodities shipped, their value, weight, and mode of transportation, as well as the origin and destination of...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="csv" data-organization="Department of Commerce" href="http://www.census.gov/econ/cfs/">CSV</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/fertilizer-use-and-price">Fertilizer Use and Price</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="64 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 64 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Agriculture </p>\n<div>This product brings together 1960-2012 data on fertilizer consumption in the United States by plant nutrient and major selected product, as well as consumption of...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="html" data-organization="Department of Agriculture" href="https://www.ers.usda.gov/data-products/fertilizer-use-and-price.aspx" target="_blank">HTML</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<a href="/dataset/food-a-pedia">Food-a-pedia</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="60 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 60 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">Department of Agriculture </p>\n<div>Find the calorie content of any food or beverage using the Food-a-pedia, looking at the Nutrition Facts label, or checking product or restaurant websites\n</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="html" data-organization="Department of Agriculture" href="https://www.supertracker.usda.gov/foodapedia.aspx" target="_blank">HTML</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<span class="dataset-collection label">\n<i class="icon-collection"/>\n                Collection\n            </span>\n<a href="/dataset/national-elevation-dataset-ned-1-3-arc-second-downloadable-data-collection-national-geospatial">1/3rd Arc-second Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="52 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 52 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">U.S. Geological Survey, Department of the Interior </p>\n<div>This layer of the National Elevation Dataset (NED) is 1/3 arc-second (approximately 10 m) resolution. The1/3 arc-second NED are derived from diverse source data that...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1-3_arc-second/">WAF</a>\n</li>\n<li>\n<a class="label" data-format="gridfloat" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/13/ArcGrid/">GridFloat</a>\n</li>\n<li>\n<a class="label" data-format="arcgrid" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/13/GridFloat/">ArcGrid</a>\n</li>\n<li>\n<a class="label" data-format="img" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/13/IMG/">IMG</a>\n</li>\n<li>\n<a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer" target="_blank">Esri REST</a>\n</li>\n<li>\n<a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/national-elevation-dataset-ned-1-3-arc-second-downloadable-data-collection-national-geospatial/resource/90ff3aea-635c-425c-968b-c128c13eb9bc">WMS</a>\n</li>\n<li>\n<a class="more" href="/dataset/national-elevation-dataset-ned-1-3-arc-second-downloadable-data-collection-national-geospatial">6 more in dataset</a>\n</li>\n</ul>\n</div>,
#  <div class="dataset-content">\n<div class="organization-type-wrap">\n<span class="organization-type" data-organization-type="federal" title="Federal Government">\n<span>Federal</span>\n</span>\n</div>\n<h3 class="dataset-heading">\n<span class="dataset-collection label">\n<i class="icon-collection"/>\n                Collection\n            </span>\n<a href="/dataset/usgs-us-topo-map-collection">USGS US Topo Map Collection</a>\n<!-- Snippet snippets/popular.html start -->\n<span class="recent-views" title="50 recent views" xmlns="http://www.w3.org/1999/xhtml">\n<i class="fa fa-line-chart"/> 50 recent views\n</span>\n<!-- Snippet snippets/popular.html end -->\n</h3>\n<div class="notes">\n<p class="dataset-organization">U.S. Geological Survey, Department of the Interior </p>\n<div>Layered GeoPDF 7.5 Minute Quadrangle Map. Layers of geospatial data include orthoimagery, roads, grids, geographic names, elevation contours, hydrography, and other...</div>\n</div>\n<ul class="dataset-resources unstyled">\n<li>\n<a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="http://thor-f5.er.usgs.gov/ngtoc/metadata/ustopo/">WAF</a>\n</li>\n<li>\n<a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="http://services.nationalmap.gov/ArcGIS/rest/services/US_Topo/MapServer" target="_blank">Esri REST</a>\n</li>\n<li>\n<a class="label" data-format="csw" data-organization="U.S. Geological Survey, Department of the Interior" href="https://www.sciencebase.gov/catalog/item/4f554236e4b018de15819c85/csw?service=CSW&amp;version=2.0.2&amp;request=GetRecords">csw</a>\n</li>\n<li>\n<a class="label" data-format="oai-pmh" data-organization="U.S. Geological Survey, Department of the Interior" href="https://www.sciencebase.gov/catalog/oai-pmh?verb=ListRecords&amp;set=4f554236e4b018de15819c85&amp;metadataPrefix=fgdc-orig">OAI-PMH</a>\n</li>\n<li>\n<a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-us-topo-map-collection/resource/1c39eb7a-09c7-4520-a051-a61d77d47b41">WMS</a>\n</li>\n<li>\n<a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-us-topo-map-collection/resource/27b79add-d3f7-4e52-a65f-432da12e4f48">WMS</a>\n</li>\n<li>\n<a class="more" href="/dataset/usgs-us-topo-map-collection">6 more in dataset</a>\n</li>\n</ul>\n</div>]

# %%
type(collset_content[0])
# Out:
# bs4.element.Tag

# %%
collset1 = collset_content[0]

# %%
print collset1.prettify()
# Out:
# <div class="dataset-content">
#  <div class="organization-type-wrap">
#   <span class="organization-type" data-organization-type="federal" title="Federal Government">
#    <span>
#     Federal
#    </span>
#   </span>
#  </div>
#  <h3 class="dataset-heading">
#   <span class="dataset-collection label">
#    <i class="icon-collection"/>
#    Collection
#   </span>
#   <a href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">
#    1 meter Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection
#   </a>
#   <!-- Snippet snippets/popular.html start -->
#   <span class="recent-views" title="256 recent views" xmlns="http://www.w3.org/1999/xhtml">
#    <i class="fa fa-line-chart"/>
#    256 recent views
#   </span>
#   <!-- Snippet snippets/popular.html end -->
#  </h3>
#  <div class="notes">
#   <p class="dataset-organization">
#    U.S. Geological Survey, Department of the Interior
#   </p>
#   <div>
#    This is a tiled collection of the 3D Elevation Program (3DEP) and is one meter resolution. Data in this layer represent a bare earth surface.The 3DEP data holdings...
#   </div>
#  </div>
#  <ul class="dataset-resources unstyled">
#   <li>
#    <a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1_meter/">
#     WAF
#    </a>
#   </li>
#   <li>
#    <a class="label" data-format="img" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/1m/IMG/">
#     IMG
#    </a>
#   </li>
#   <li>
#    <a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer" target="_blank">
#     Esri REST
#    </a>
#   </li>
#   <li>
#    <a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-/resource/98e1752e-cf04-4df3-be2f-b58bee5a3c06">
#     WMS
#    </a>
#   </li>
#   <li>
#    <a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://nationalmap.gov/elevation.html" target="_blank">
#     HTML
#    </a>
#   </li>
#   <li>
#    <a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://viewer.nationalmap.gov/" target="_blank">
#     HTML
#    </a>
#   </li>
#   <li>
#    <a class="more" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">
#     1 more in dataset
#    </a>
#   </li>
#  </ul>
# </div>

# %%
collset1.name
# Out:
# 'div'

# %%
collset1.attrs
# Out:
# {'class': u'dataset-content'}

# %%
collset1['class']
# Out:
# u'dataset-content'

# %%
for child in collset1.children:
    print child.name
# Out:
# None
# div
# None
# h3
# None
# div
# None
# ul
# None

# %%
collset1.ul.find_all('li')
# Out:
# [<li>\n<a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1_meter/">WAF</a>\n</li>,
#  <li>\n<a class="label" data-format="img" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/1m/IMG/">IMG</a>\n</li>,
#  <li>\n<a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer" target="_blank">Esri REST</a>\n</li>,
#  <li>\n<a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-/resource/98e1752e-cf04-4df3-be2f-b58bee5a3c06">WMS</a>\n</li>,
#  <li>\n<a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://nationalmap.gov/elevation.html" target="_blank">HTML</a>\n</li>,
#  <li>\n<a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://viewer.nationalmap.gov/" target="_blank">HTML</a>\n</li>,
#  <li>\n<a class="more" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">1 more in dataset</a>\n</li>]

# %% [markdown]
# While going through the list items is one way to extract the dataset url's, I'd rather just use the 'a' tag instead.

# %%
aset1 = collset1.find_all('a')

# %%
print aset1
# Out:
# [<a href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">1 meter Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection</a>, <a class="label" data-format="waf" data-organization="U.S. Geological Survey, Department of the Interior" href="https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1_meter/">WAF</a>, <a class="label" data-format="img" data-organization="U.S. Geological Survey, Department of the Interior" href="https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/1m/IMG/">IMG</a>, <a class="label" data-format="esri rest" data-organization="U.S. Geological Survey, Department of the Interior" href="https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer" target="_blank">Esri REST</a>, <a class="label" data-format="wms" data-organization="U.S. Geological Survey, Department of the Interior" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-/resource/98e1752e-cf04-4df3-be2f-b58bee5a3c06">WMS</a>, <a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://nationalmap.gov/elevation.html" target="_blank">HTML</a>, <a class="label" data-format="html" data-organization="U.S. Geological Survey, Department of the Interior" href="https://viewer.nationalmap.gov/" target="_blank">HTML</a>, <a class="more" href="/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-">1 more in dataset</a>]

# %% [markdown]
# Here is the title of the dataset collection, let's make a script to extract the title and href's from the 'a' tags.

# %%
aset1[0].text
# Out:
# u'1 meter Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection'

# %%
aset1[0].attrs
# Out:
# {'href': u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-'}

# %%
adict = {'label':[],'coll':[],'more':[]}
for a in aset1:
    try:
        adict[a['class']].append(a['href'])
    except KeyError:
        adict['coll'].append(a['href'])
        collname = a.text.strip()

# %%
collname
# Out:
# u'1 meter Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection'

# %%
adict
# Out:
# {'coll': [u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-'],
#  'label': [u'https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1_meter/',
#   u'https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/1m/IMG/',
#   u'https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer',
#   u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-/resource/98e1752e-cf04-4df3-be2f-b58bee5a3c06',
#   u'https://nationalmap.gov/elevation.html',
#   u'https://viewer.nationalmap.gov/'],
#  'more': [u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-']}

# %% [markdown]
# We are also able to get the description component of the collection.

# %%
collnotes = collset1.find('div',attrs={'class':'notes'})

# %%
print collnotes.prettify()
# Out:
# <div class="notes">
#  <p class="dataset-organization">
#   U.S. Geological Survey, Department of the Interior
#  </p>
#  <div>
#   This is a tiled collection of the 3D Elevation Program (3DEP) and is one meter resolution. Data in this layer represent a bare earth surface.The 3DEP data holdings...
#  </div>
# </div>

# %%
collnotes.p.text.strip()
# Out:
# u'U.S. Geological Survey, Department of the Interior'

# %%
collnotes.div.text.strip()
# Out:
# u'This is a tiled collection of the 3D Elevation Program (3DEP) and is one meter resolution. Data in this layer represent a bare earth surface.The 3DEP data holdings...'

# %%
collorg = collnotes.p.text.strip()
colldesc = collnotes.div.text.strip()

# %% [markdown]
# Now that we have some code to process the collection html, let's create a def to modularize this section.

# %%
def process_collset(collset1):
    """
    Processes the data.gov html within the tags <div class = dataset-content>...
    Input: html string
    Output: tuple of title (string), organization (string), 
      description (string), hrefs (dictionary)
    """
    aset1 = collset1.find_all('a')
    adict = {'label':[],'coll':[],'more':[]}
    for a in aset1:
        try:
            adict[a['class']].append(a['href'])
        except KeyError:
            adict['coll'].append(a['href'])
            collname = a.text.strip()
    collnotes = collset1.find('div',attrs={'class':'notes'})
    collorg = collnotes.p.text.strip()
    colldescdiv = collnotes.div
    if colldescdiv:
        colldesc = colldescdiv.text.strip()
    else:
        colldesc = ""
    return collname, collorg, colldesc, adict

# %%
help(process_collset)
# Out:
# Help on function process_collset in module __main__:
#
# process_collset(collset1)
#     Processes the data.gov html within the tags <div class = dataset-content>...
#     Input: html string
#     Output: tuple of title (string), organization (string),
#       description (string), hrefs (dictionary)

# %%
collname, collorg, colldesc, adict = process_collset(collset1)

# %%
collname
# Out:
# u'1 meter Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection'

# %%
collorg
# Out:
# u'U.S. Geological Survey, Department of the Interior'

# %%
colldesc
# Out:
# u'This is a tiled collection of the 3D Elevation Program (3DEP) and is one meter resolution. Data in this layer represent a bare earth surface.The 3DEP data holdings...'

# %%
adict
# Out:
# {'coll': [u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-'],
#  'label': [u'https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1_meter/',
#   u'https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/1m/IMG/',
#   u'https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer',
#   u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-/resource/98e1752e-cf04-4df3-be2f-b58bee5a3c06',
#   u'https://nationalmap.gov/elevation.html',
#   u'https://viewer.nationalmap.gov/'],
#  'more': [u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-']}

# %%
for collset in collset_content:
    collname = process_collset(collset)[0]
    print collname
# Out:
# 1 meter Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection
# U.S. Hourly Precipitation Data
# Farm Programs Payments
# National Flood Hazard Layer (NFHL)
# Food Environment Atlas
# Food Price Outlook
# Military Installations, Ranges, and Training Areas
# NCDC Storm Events Database
# Statistical Abstract of the United States
# USGS National Transportation Dataset (NTD) Downloadable Data Collection
# U.S. Monthly Climate Normals (1981-2010)
# Fruit and Vegetable Prices
# MyPyramid Food Raw Data
# CDC WONDER: Cancer Statistics
# Population Estimates
# Commodity Flow Survey
# Fertilizer Use and Price
# Food-a-pedia
# 1/3rd Arc-second Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection
# USGS US Topo Map Collection

# %% [markdown]
# Let's modularize the queries from data.gov.

# %%
def clim_page(urlbase = "https://catalog.data.gov/dataset", groups="climate5434",
              page=1):
    """
    Queries the data.gov climate change data search for a specific page
    Input: urlbase, groups, page (strings)
    Output: list of dataset-content 
    """
    dataparams = {"groups":groups,"page":page}
    climreq = requests.get(urlbase,params = dataparams)
    clim_bs = BeautifulSoup(climreq.text,'lxml-xml')
    collset_content = clim_bs.find_all(name='div',attrs={'class':'dataset-content'})
    return collset_content

# %%
clim = clim_page(page=2)

# %%
print [process_collset(c)[0] for c in clim]
# Out:
# [u'Forest Inventory and Analysis Database', u'USGS Map service: Coastal Vulnerability to Sea-Level Rise', u'USGS US Topo Map Collection', u'1/3rd Arc-second Digital Elevation Models (DEMs) - USGS National Map 3DEP Downloadable Data Collection', u'Aquaculture Data', u'U.S. Daily Climate Normals (1981-2010)', u'United States Average Annual Precipitation, 1990-2009 - Direct Download', u'USGS Water-Quality Data for the Nation - National Water Information System (NWIS)', u'CMS Statistics', u'Quick Stats Agricultural Database API', u'U.S. Food Imports', u'Organic Prices', u'National Bridge Inventory - National Geospatial Data Asset (NGDA) Bridges', u'Feed Grains Database', u'National Hydrography Dataset (NHD) - USGS National Map Downloadable Data Collection', u'Food Access Research Atlas', u'Monthly Summaries of the Global Historical Climatology Network - Daily (GHCN-D)', u'Global Forecast System (GFS) [0.5 Deg.]', u'NASIS', u'Watershed Boundary Dataset (WBD) - USGS National Map Downloadable Data Collection']

# %% [markdown]
# Here we extract all of the pages from the climate group from data.gov.

# %%
page_num_max = 34
climate_colls = []
for page_num in xrange(1,page_num_max+1):
    try:
        clim = clim_page(page=page_num)
        if clim != None:
            climate_colls += [process_collset(c) for c in clim]
        else:
            break
    except requests.HTTPError:
        break

# %%
climate_colls.__len__()
# Out:
# 666

# %%
climate_colls[0][3]
# Out:
# {'coll': [u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-'],
#  'label': [u'https://thor-f5.er.usgs.gov/ngtoc/metadata/waf/elevation/1_meter/',
#   u'https://prd-tnm.s3.amazonaws.com/index.html?prefix=StagedProducts/Elevation/1m/IMG/',
#   u'https://services.nationalmap.gov/arcgis/rest/services/3DEPElevationIndex/MapServer',
#   u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-/resource/98e1752e-cf04-4df3-be2f-b58bee5a3c06',
#   u'https://nationalmap.gov/elevation.html',
#   u'https://viewer.nationalmap.gov/'],
#  'more': [u'/dataset/usgs-national-elevation-dataset-ned-1-meter-downloadable-data-collection-from-the-national-map-']}

# %% [markdown]
# I'll build a dataframe so that I can count the data collections by organization.

# %%
climate_df = pd.DataFrame({'name':c[0],'organization':c[1],'description':c[2]}
                          for c in climate_colls)

# %%
climate_df
# Out:
#                                            description  \
# 0    This is a tiled collection of the 3D Elevation...
# 1    Hourly Precipitation Data (HPD) is digital dat...
# 2    Payments made by the Department of Agriculture...
# 3    The National Flood Hazard Layer (NFHL) is a co...
# 4    Food environment factors--such as store/restau...
# 5    The Consumer Price Index (CPI) for food is a c...
# 6    This dataset, released by DoD, contains geogra...
# 7    Storm Data is provided by the National Weather...
# 8    First published in 1878, the Statistical Abstr...
# 9    The USGS Transportation downloadable data from...
# 10   The U.S. Monthly Climate Normals for 1981 to 2...
# 11   How much do fruits and vegetables cost? ERS es...
# 12   MyPyramid Food Data provides information on th...
# 13   The United States Cancer Statistics (USCS) onl...
# 14   The program publishes estimates of the populat...
# 15   The Commodity Flow Survey provides information...
# 16   This product brings together 1960-2012 data on...
# 17   Find the calorie content of any food or bevera...
# 18   This layer of the National Elevation Dataset (...
# 19   Layered GeoPDF 7.5 Minute Quadrangle Map. Laye...
# 20   The Forest Inventory and Analysis (FIA) resear...
# 21   The coastal vulnerability index (CVI)provides ...
# 22   Layered GeoPDF 7.5 Minute Quadrangle Map. Laye...
# 23   This layer of the National Elevation Dataset (...
# 24   Aquaculture is the production of aquatic anima...
# 25   The U.S. Daily Climate Normals for 1981 to 201...
# 26   This map layer shows polygons of average annua...
# 27   The USGS compiles online access to water-resou...
# 28   The CMS Center for Strategic Planning produces...
# 29   Quick Stats API is the programmatic interface ...
# ..                                                 ...
# 636  This data depicts the social vulnerability of ...
# 637  This data set contains vector polygons represe...
# 638  Baseline (1961-1990) average total precipitati...
# 639  The Multisensor Analyzed Sea Ice Extent Northe...
# 640  IceBridge LVIS L2 Geolocated Surface Elevation...
# 641  The Rail Network is a comprehensive database o...
# 642  This data set, part of the NASA Making Earth S...
# 643  The data set consists of monthly global snow c...
# 644
# 645  The NOAA Ocean Surface Bundle (OSB) Climate Da...
# 646  U.S. Geological Survey, Department of the Inte...
# 647  This data set represents the estimated area of...
# 648  Temperature, salinity, and other data were col...
# 649  The MEaSUREs Global Record of Daily Landscape ...
# 650  This map layer shows the locations of wells ma...
# 651  The National Ambulatory Medical Care Survey (N...
# 652  This EnviroAtlas dataset categorizes land cove...
# 653  This data set contains products from depth sou...
# 654  This archive contains daily surface meteorolog...
# 655  IceBridge LVIS L1B Geolocated Return Energy Wa...
# 656  This EnviroAtlas dataset includes annual nitro...
# 657  This EnviroAtlas dataset contains data on the ...
# 658  The Solar Energy Environmental Mapper is a web...
# 659  The Passive Microwave Sea Ice Concentration Cl...
# 660  This data set contains sensitive biological re...
# 661  The North American Mesoscale Forecast System (...
# 662  IceBridge ATM L4 Surface Elevation Rate of Change
# 663  This data set contains the forcing data for Ph...
# 664  Baseline (1961-1990) average annual temperatur...
# 665  This data set represents the area of each leve...
#
#                                                   name  \
# 0    1 meter Digital Elevation Models (DEMs) - USGS...
# 1                       U.S. Hourly Precipitation Data
# 2                               Farm Programs Payments
# 3                   National Flood Hazard Layer (NFHL)
# 4                               Food Environment Atlas
# 5                                   Food Price Outlook
# 6    Military Installations, Ranges, and Training A...
# 7                           NCDC Storm Events Database
# 8            Statistical Abstract of the United States
# 9    USGS National Transportation Dataset (NTD) Dow...
# 10            U.S. Monthly Climate Normals (1981-2010)
# 11                          Fruit and Vegetable Prices
# 12                             MyPyramid Food Raw Data
# 13                       CDC WONDER: Cancer Statistics
# 14                                Population Estimates
# 15                               Commodity Flow Survey
# 16                            Fertilizer Use and Price
# 17                                        Food-a-pedia
# 18   1/3rd Arc-second Digital Elevation Models (DEM...
# 19                         USGS US Topo Map Collection
# 20              Forest Inventory and Analysis Database
# 21   USGS Map service: Coastal Vulnerability to Sea...
# 22                         USGS US Topo Map Collection
# 23   1/3rd Arc-second Digital Elevation Models (DEM...
# 24                                    Aquaculture Data
# 25              U.S. Daily Climate Normals (1981-2010)
# 26   United States Average Annual Precipitation, 19...
# 27   USGS Water-Quality Data for the Nation - Natio...
# 28                                      CMS Statistics
# 29               Quick Stats Agricultural Database API
# ..                                                 ...
# 636  Social Vulnerability Index (SoVI) for Coastal ...
# 637  Sensitivity of Coastal Environments and Wildli...
# 638  Baseline (1961-1990) average total precipitati...
# 639  Multisensor Analyzed Sea Ice Extent  - Norther...
# 640  IceBridge LVIS L2 Geolocated Surface Elevation...
# 641  Rail Nodes (National) - National Geospatial Da...
# 642  MEaSUREs Arctic Sea Ice Characterization Daily...
# 643  Nimbus-7 SMMR Derived Monthly Global Snow Cove...
# 644  Plankton abundance, Biomass, Temperature, Sali...
# 645  NOAA Climate Data Record (CDR) of Ocean Near S...
# 646  USGS Watershed Boundary Dataset (WBD) Stewards...
# 647  Attributes for NHDPlus Catchments (Version 1.1...
# 648  Temperature, salinity, and other data from buo...
# 649  MEaSUREs Global Record of Daily Landscape Free...
# 650  Ground-Water Climate Response Network - Direct...
# 651    National Ambulatory Medical Care Survey (NAMCS)
# 652  EnviroAtlas - MSPA connectivity with water mis...
# 653  IceBridge MCoRDS L3 Gridded Ice Thickness, Sur...
# 654  University of Idaho Daily Meteorological data ...
# 655  IceBridge LVIS L1B Geolocated Return Energy Wa...
# 656  EnviroAtlas - Atmospheric Nitrogen Deposition ...
# 657  EnviroAtlas - Biological nitrogen fixation in ...
# 658                  Solar Energy Environmental Mapper
# 659  NOAA Climate Data Record (CDR) of Passive Micr...
# 660  Sensitivity of Coastal Environments and Wildli...
# 661  North American Mesoscale Forecast System (NAM)...
# 662  IceBridge ATM L4 Surface Elevation Rate of Cha...
# 663  NLDAS Forcing Data L4 Monthly 0.125 x 0.125 de...
# 664  Average historical annual temperature, project...
# 665  Attributes for NHDPlus Catchments (Version 1.1...
#
#                                           organization
# 0    U.S. Geological Survey, Department of the Inte...
# 1    National Oceanic and Atmospheric Administratio...
# 2                            Department of Agriculture
# 3                      Department of Homeland Security
# 4                            Department of Agriculture
# 5                            Department of Agriculture
# 6                                Department of Defense
# 7    National Oceanic and Atmospheric Administratio...
# 8                               Department of Commerce
# 9    U.S. Geological Survey, Department of the Inte...
# 10   National Oceanic and Atmospheric Administratio...
# 11                           Department of Agriculture
# 12                           Department of Agriculture
# 13           U.S. Department of Health  Human Services
# 14                              Department of Commerce
# 15                              Department of Commerce
# 16                           Department of Agriculture
# 17                           Department of Agriculture
# 18   U.S. Geological Survey, Department of the Inte...
# 19   U.S. Geological Survey, Department of the Inte...
# 20        US Forest Service, Department of Agriculture
# 21   U.S. Geological Survey, Department of the Inte...
# 22   U.S. Geological Survey, Department of the Inte...
# 23   U.S. Geological Survey, Department of the Inte...
# 24                           Department of Agriculture
# 25   National Oceanic and Atmospheric Administratio...
# 26   U.S. Geological Survey, Department of the Inte...
# 27   U.S. Geological Survey, Department of the Inte...
# 28           U.S. Department of Health  Human Services
# 29                           Department of Agriculture
# ..                                                 ...
# 636  National Oceanic and Atmospheric Administratio...
# 637  National Oceanic and Atmospheric Administratio...
# 638          Arctic Landscape Conservation Cooperative
# 639  National Oceanic and Atmospheric Administratio...
# 640      National Aeronautics and Space Administration
# 641                       Department of Transportation
# 642      National Aeronautics and Space Administration
# 643      National Aeronautics and Space Administration
# 644  National Oceanic and Atmospheric Administratio...
# 645  National Oceanic and Atmospheric Administratio...
# 646  U.S. Geological Survey, Department of the Inte...
# 647  U.S. Geological Survey, Department of the Inte...
# 648  National Oceanic and Atmospheric Administratio...
# 649      National Aeronautics and Space Administration
# 650  U.S. Geological Survey, Department of the Inte...
# 651          U.S. Department of Health  Human Services
# 652               U.S. Environmental Protection Agency
# 653      National Aeronautics and Space Administration
# 654  U.S. Geological Survey, Department of the Inte...
# 655      National Aeronautics and Space Administration
# 656               U.S. Environmental Protection Agency
# 657               U.S. Environmental Protection Agency
# 658                               Department of Energy
# 659  National Oceanic and Atmospheric Administratio...
# 660  National Oceanic and Atmospheric Administratio...
# 661  National Oceanic and Atmospheric Administratio...
# 662      National Aeronautics and Space Administration
# 663      National Aeronautics and Space Administration
# 664          Arctic Landscape Conservation Cooperative
# 665  U.S. Geological Survey, Department of the Inte...
#
# [666 rows x 3 columns]

# %%
org_count = climate_df.groupby('organization').count()

# %%
org_count.sort_values(by='name',ascending=False)
# Out:
#                                                     description  name
# organization
# National Oceanic and Atmospheric Administration...          179   179
# U.S. Geological Survey, Department of the Interior          119   119
# National Aeronautics and Space Administration               115   115
# Department of Agriculture                                    62    62
# Department of Energy                                         42    42
# Arctic Landscape Conservation Cooperative                    41    41
# U.S. Department of Health  Human Services                    28    28
# Department of Transportation                                 27    27
# U.S. Environmental Protection Agency                         22    22
# US Forest Service, Department of Agriculture                  8     8
# Department of Commerce                                        5     5
# US Census Bureau, Department of Commerce                      5     5
# US Fish and Wildlife Service, Department of the...            4     4
# Department of Housing and Urban Development                   2     2
# Federal Geographic Data Committee                             2     2
# Bureau of Land Management, Department of the In...            1     1
# Kansas Data Access and Support Center                         1     1
# Department of the Interior                                    1     1
# Department of Homeland Security                               1     1
# Department of Defense                                         1     1

# %%
org_count_abbr = org_count[org_count['name'] > 20]

# %%
rem_count = org_count[org_count['name'] <= 20].sum()[0]

# %%
type(rem_count)
# Out:
# numpy.int64

# %%
org_count_abbr = org_count_abbr.append(pd.DataFrame({'name':[rem_count]}, 
                                                    index=['Other']))
org_count_abbr = org_count_abbr[['name']].rename(columns={'name':'count'})

# %%
org_count_abbr
# Out:
#                                                     count
# organization
# Arctic Landscape Conservation Cooperative              41
# Department of Agriculture                              62
# Department of Energy                                   42
# Department of Transportation                           27
# National Aeronautics and Space Administration         115
# National Oceanic and Atmospheric Administration...    179
# U.S. Department of Health  Human Services              28
# U.S. Environmental Protection Agency                   22
# U.S. Geological Survey, Department of the Interior    119
# Other                                                  31

# %%
_ = org_count_abbr.sort_values(by='count',ascending=False).plot(y='count',kind='bar')

# %%
org_sorted = org_count_abbr.sort_values(by='count',ascending=False).index.values

# %% [markdown]
# # Tracking the status of datasets
# Let's make some defs to query the dataset urls.  The first is for converting relative paths to urls, and the second returns the status of the request to that url.

# %%
def reltoabs(url,urlbase = "https://catalog.data.gov"):
    """
    Input: url string
    Output: url string
    """
    if url[0]=='/':
        return urlbase+url
    else:
        return url

# %%
def testurl(url):
    """
    Input: url
    Output: request status code
    """
    try:
        if url[:4] == 'http':
            r = requests.head(url)
            return r.status_code
    except requests.ConnectionError:
        return None
    if url[:3] == 'ftp':
        r = requests_ftp(url)
        return r.status_code

# %%
urlstats=[]
for coll in climate_colls:
    urlstattemp = []
    for urlrel in coll[3]['label']:
        url = reltoabs(urlrel)
        urlstatus = testurl(url)
        urlstattemp += [urlstatus]
    urlstats.append(urlstattemp)

# %% [markdown]
# We can see that urlstats contains the request status of the urls that are listed on data.gov.  So let's make a def that converts each list of status returns into a dict of counts of each type.  This way we can pass it to pd.DataFrame

# %%
urlstats[0:10]
# Out:
# [[200, 200, 404, 503, 200, 302],
#  [301, 301, 200, None, 301, 200],
#  [200],
#  [200, 200, 301, 302, 301, 301],
#  [200, 405, 200],
#  [200],
#  [200],
#  [301, 301, 301, 301, 301, 301],
#  [200],
#  [200, 200, 200, 404, 200, 301]]

# %%
def convstatnames(stats):
    """Return a dictionary of counts"""
    sdict = dict(Counter(stats))
    return {'status_'+str(a):b for a,b in sdict.items()}

stat_df = pd.DataFrame([convstatnames(stats) for stats in urlstats])
stat_df = stat_df.fillna(0)
stat_df.head()

failedstatus = ['status_400','status_404','status_405','status_503','status_None']
stat_df['failed ratio'] = stat_df[failedstatus].sum(axis=1)/stat_df.sum(axis=1)

# %% [markdown]
# We've also created a variable which is the proportion of urls that returned a status in the 400's or 500's or None.  Let's now join this against the climate_df to get one DataFrame of all unique combinations of failed ratio and organization.  Retain only the most common organizations.

# %%
climate_df = climate_df.join(stat_df)
climate_failed = climate_df.groupby(['organization','failed ratio'])
failed_count = climate_failed.count()[['name']].rename(columns={'name':'count'})
failed_count = failed_count.reset_index()
red_orgs = org_count[org_count['name'] > 20].index
failed_count_red = failed_count[[org in red_orgs for org in failed_count['organization']]]
failed_count_red.head()

# %%
org_numbers = {org_sorted[i]:i+1 for i in range(len(org_sorted))}
failed_count_red['org number'] = failed_count_red['organization'].apply(lambda o: org_numbers[o])
# Out:
# C:\Users\James Sharpnack\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
failed_count_red.head()
# Out:
#                                 organization  failed ratio  count  org number
# 0  Arctic Landscape Conservation Cooperative      0.000000     41           6
# 2                  Department of Agriculture      0.000000     48           4
# 3                  Department of Agriculture      0.250000      1           4
# 4                  Department of Agriculture      0.333333      3           4
# 5                  Department of Agriculture      0.500000      1           4

# %%
from operator import itemgetter
norgs=len(org_numbers)
_ = failed_count_red.plot(x = 'org number',y = 'failed ratio',xticks=range(1,norgs+1),
                      s=failed_count['count']*4,kind='scatter',marker='s')
for orgname,i in sorted(org_numbers.items(),key=itemgetter(1)):
    print "{}: {}".format(i,orgname)
# Out:
# 1: National Oceanic and Atmospheric Administration, Department of Commerce
# 2: U.S. Geological Survey, Department of the Interior
# 3: National Aeronautics and Space Administration
# 4: Department of Agriculture
# 5: Department of Energy
# 6: Arctic Landscape Conservation Cooperative
# 7: Other
# 8: U.S. Department of Health  Human Services
# 9: Department of Transportation
# 10: U.S. Environmental Protection Agency
